# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
url = 'https://tjhsst.fcps.edu/academics'

# %%
page = requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="ie6 lt-ie9 lt-ie8 lt-ie7 no-js" lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 7]>         <html class="ie7 lt-ie9 lt-ie8 no-js" lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 8]>         <html class="ie8 lt-ie9 no-js" lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 9]>         <html class="ie9 no-js" lang="en" dir="ltr"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js" dir="ltr" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"869a1a293e",applicationID:"71440368"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n,r){return function(){return s.recordSupportability("API/"+e+"/called"),o(t+e,[u.now()].concat(c(arguments)),n?null:this,r),n?void 0:this}}var o=t("handle"),a=t(10),c=t(11),f=t("ee").get("tracer"),u=t("loader"),s=t(4),d=NREUM;"undefined"==typeof window.newrelic&&(newrelic=d);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",v=l+"ixn-";a(p,function(t,e){d[e]=i(l,e,!0,"api")}),d.addPageAction=i(l,"addPageAction",!0),d.setCurrentRouteName=i(l,"routeName",!0),e.exports=newrelic,d.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(v+"tracer",[u.now(),t,n],r),function(){if(f.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw f.emit("fn-err",[arguments,this,t],n),t}finally{f.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(v,e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),s.recordSupportability("API/noticeError/called"),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){var r=!1;try{var i=Object.defineProperty({},"passive",{get:function(){r=!0}});window.addEventListener("testPassive",null,i),window.removeEventListener("testPassive",null,i)}catch(o){}e.exports=function(t){return r?{passive:!0,capture:!!t}:!!t}},{}],4:[function(t,e,n){function r(t,e){var n=[a,t,{name:t},e];return o("storeMetric",n,null,"api"),n}function i(t,e){var n=[c,t,{name:t},e];return o("storeEventMetrics",n,null,"api"),n}var o=t("handle"),a="sm",c="cm";e.exports={constants:{SUPPORTABILITY_METRIC:a,CUSTOM_METRIC:c},recordSupportability:r,recordCustom:i}},{}],5:[function(t,e,n){function r(){return c.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,c=t(12);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],6:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],7:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?l("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&l("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();if(n.length>0){var r=n[n.length-1];if(u&&u<r.startTime)return;var i=[r],o=a({});o&&i.push(o),l("lcp",i)}}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||l("cls",[t])})}function a(t){var e=navigator.connection||navigator.mozConnection||navigator.webkitConnection;if(e)return e.type&&(t["net-type"]=e.type),e.effectiveType&&(t["net-etype"]=e.effectiveType),e.rtt&&(t["net-rtt"]=e.rtt),e.downlink&&(t["net-dlink"]=e.downlink),t}function c(t){if(t instanceof y&&!w){var e=Math.round(t.timeStamp),n={type:t.type};a(n),e<=v.now()?n.fid=v.now()-e:e>v.offset&&e<=Date.now()?(e-=v.offset,n.fid=v.now()-e):e=v.now(),w=!0,l("timing",["fi",e,n])}}function f(t){"hidden"===t&&(u=v.now(),l("pageHide",[u]))}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var u,s,d,p,l=t("handle"),v=t("loader ...
#   </script>
#   <noscript>
#    <style>
#     form.antibot * :not(.antibot-message) { display: none !important; }
#    </style>
#   </noscript>
#   <link href="/sites/default/files/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/sites/default/files/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/sites/default/files/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/sites/default/files/favicons/site.webmanifest" rel="manifest"/>
#   <link color="#5bbad5" href="/sites/default/files/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#da532c" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="Drupal responsive_favicons + realfavicongenerator.net" name="favicon-generator"/>
#   <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://tjhsst.fcps.edu/academics" rel="canonical"/>
#   <link href="https://tjhsst.fcps.edu/node/323" rel="shortlink"/>
#   <link href="https://tjhsst.fcps.edu/academics" rel="revision"/>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0];var j=d.createElement(s);var dl=l!='dataLayer'?'&l='+l:'';j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl+'';j.async=true;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-NDP35T');
#   </script>
#   <title>
#    Academics | Thomas Jefferson High School for Science and Technology
#   </title>
#   <link href="/sites/default/files/css/css_F2gAVVlSdR3arDUpXp31o79SNgjcEodwd2bnXsnktzU.css" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/css_qLLa0fjxzXjbti0Orln7hrTaNyPa4k-xxnc6qhu8ET4.css" media="all" rel="stylesheet"/>
#   <link href="//addtocalendar.com/atc/1.5/atc-style-menu-wb.css" media="all" rel="stylesheet"/>
#   <link href="//fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,700,700italic|Arimo:400,400italic,700,700italic" media="all" rel="stylesheet"/>
#   <!--[if gte IE 9]><!-->
#   <link href="/sites/default/files/css/css_vJikm4_bcHTyPthFqjhMXbEYuxmXu-DDEs1qvUcK9fM.css" media="all" rel="stylesheet"/>
#   <!--<![endif]-->
#   <link href="/sites/default/files/css/css_vzVKUq7TwP7gm4NwMDu1AHrGMjU4MkdjFlm4uwbW6ds.css" media="all" rel="stylesheet"/>
#   <script src="/core/assets/vendor/modernizr/modernizr.min.js?v=3.11.7">
#   </script>
#   <script src="/core/misc/modernizr-additional-tests.js?v=3.11.7">
#   </script>
#  </head>
#  <body class="path-node not-front page--node-type-landing-page fcps-dark-color-1 fcps-light-color-2">
#   <noscript aria-hidden="true">
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NDP35T" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#    <div class="page-container remodal-bg">
#     <div class="skiplinks">
#      <a class="skiplinks__link element-focusable" href="#main">
#       Skip to main content
#      </a>
#     </div>
#     <nav class="block block--menu-block" id="fullmenu" role="navigation">
#      <h2 class="element-invisible block__title">
#       Full Menu
#      </h2>
#      <ul class="nav nav--full-menu">
#       <li class="nav__item">
#        <a class="nav__link" data-drupal-link-system-path="&lt;front&gt;" href="/">
#         Homepage
#        </a>
#       </li>
#       <li class="nav__item">
#        <a class="nav__link" data-drupal-link-system-path="node/299" href="/about">
#         About
#        </a>
#        <ul class="nav nav--full-menu__subnav">
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/327" href="/about/administration">
#           Administration
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1901" href="/about/attendance">
#           Attendance
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/3802" href="/resources/challenge-success-program-tjhsst" title="Challenge Success Program at TJHSST">
#           Challenge Success Program
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/2871" href="/about/bell-schedules">
#           Bell Schedules
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" href="https://schoolprofiles.fcps.edu/schlprfl/f?p=108%3A50%3A%3A%3A%3A%3AP0_CURRENT_SCHOOL_ID%3A300" target="_blank">
#           FCPS School Profile
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/5693" href="/esserIII-SIIP2021-22">
#           School Innovation and Improvement Plan
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/851" href="/staff-directory">
#           Staff Directory
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/3090" href="/about/tjhsst-honor-code">
#           TJHSST Honor Code
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/3091" href="/about/tjhsst-student-advocacy">
#           TJHSST Student Advocacy
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/3271" href="/about/transportation">
#           Transportation
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="nav__item">
#        <a class="nav__link" href="https://www.fcps.edu/registration/thomas-jefferson-admissions" target="_blank">
#         Admission
#        </a>
#       </li>
#       <li class="nav__item nav__item--active-trail">
#        <a class="nav__link is-active" data-drupal-link-system-path="node/323" href="/academics">
#         Academics
#        </a>
#        <ul class="nav nav--full-menu__subnav">
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1938" href="/academics/computer-science">
#           Computer Science
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1834" href="/academics/fine-arts">
#           Fine Arts
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1905" href="/academics/humanities">
#           Humanities
#          </a>
#          <ul class="nav nav--full-menu__subnav">
#           <li class="nav__item">
#            <a class="nav__link" data-drupal-link-system-path="node/1836" href="/academics/humanities/english">
#             English
#            </a>
#           </li>
#           <li class="nav__item">
#            <a class="nav__link" data-drupal-link-system-path="node/1837" href="/academics/humanities/social-studies">
#             Social Studies
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1940" href="/academics/mathematics">
#           Mathematics
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1894" href="/academics/mentorship">
#           Mentorship
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1936" href="/academics/pe-health-driver-education">
#           PE, Health, Driver Education
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/2762" href="/academics/research-program">
#           Research Program
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1941" href="/academics/science-and-technology">
#           Science and Technology
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" href="https://insys.fcps.edu/CourseCatOnline/frontPanel/503/nocourselist/0/0/0/1" target="_blank">
#           TJHSST Course Catalog
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1942" href="/academics/world-languages">
#           World Languages
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="nav__item">
#        <a class="nav__link" data-drupal-link-system-path="node/144" href="/announcements">
#         Announcements
#        </a>
#       </li>
#       <li class="nav__item">
#        <a class="nav__link" data-drupal-link-system-path="node/1221" href="/events">
#         Events
#        </a>
#       </li>
#       <li class="nav__item">
#        <a class="nav__link" data-drupal-link-system-path="node/284" href="/features">
#         Features
#        </a>
#       </li>
#       <li class="nav__item">
#        <a class="nav__link" data-drupal-link-system-path="node/1573" href="/get-involved">
#         Get Involved
#        </a>
#       </li>
#       <li class="nav__item">
#        <a class="nav__link" data-drupal-link-system-path="node/1559" href="/library">
#         Library
#        </a>
#       </li>
#       <li class="nav__item">
#        <a class="nav__link" data-drupal-link-system-path="node/356" href="/resources">
#         Resources
#        </a>
#        <ul class="nav nav--full-menu__subnav">
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/3802" href="/resources/challenge-success-program-tjhsst">
#           Challenge Success Program at TJHSST
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/2042" href="/student-services/curricular-resources">
#           Curricular Resources
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/4858" href="/adopteddigitalresources">
#           Digital Resources at TJHSST - Parent Consent
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1899" href="/resources/health-room">
#           Health Room
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/2535" href="/resources/student-wellness-resources">
#           Student Wellness Resources
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1871" href="/resources/technology-resources">
#           Technology Resources
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1944" href="/resources/additional-resources">
#           Additional Resources
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="nav__item">
#        <a class="nav__link" data-drupal-link-system-path="node/851" href="/staff-directory">
#         Staff Directory
#        </a>
#       </li>
#       <li class="nav__item">
#        <a class="nav__link" data-drupal-link-system-path="node/322" href="/activities">
#         Student Life and Activities
#        </a>
#        <ul class="nav nav--full-menu__subnav">
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1985" href="/student-life-and-activities/8th-period-activities">
#           8th Period Activities
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1898" href="/student-life-and-activities/athletics">
#           Athletics
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1986" href="/student-life-and-activities/publications">
#           Publications
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="nav__item">
#        <a class="nav__link" data-drupal-link-system-path="node/298" href="/student-services" title="Student Services">
#         Student Services
#        </a>
#        <ul class="nav nav--full-menu__subnav">
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1904" href="/student-services/college-and-career-center">
#           College and Career Center
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/2042" href="/student-services/curricular-resources">
#           Curricular Resources
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/1945" href="/student-services/special-services">
#           Special Services
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/5521" href="/testing">
#           Testing
#          </a>
#         </li>
#         <li class="nav__item">
#          <a class="nav__link" data-drupal-link-system-path="node/2031" href="/student-services/transcript-requests">
#           Transcript Requests
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="nav__item">
#        <a class="nav__link" data-drupal-link-system-path="node/883" href="/contact">
#         Contact
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <nav class="mobile-menu" role="navigation">
#      <div class="mobile-menu__bar">
#       <a class="mobile-menu__button js-mobile-menu-button mobile-menu__button--menu" href="#fullmenu">
#        <span class="mobile-menu__icon mobile-menu__icon--menu">
#        </span>
#        <span class="mobile-menu__text">
#         Menu
#        </span>
#       </a>
#       <a class="nav__link nav__link--alert" href="/alerts" id="alerts-nav-mobile">
#        <span class="mobile-alert-icon">
#        </span>
#        <span class="mobile-alert-text">
#         Alerts
#        </span>
#       </a>
#       <a class="mobile-menu__school-name" href="/" rel="home">
#        <span>
#         Thomas Jefferson High School for Science and Technology
#        </span>
#        <img alt="Home" src="/sites/default/files/TJ%20LogoTransparent.png"/>
#       </a>
#       <a class="mobile-menu__logo" href="/">
#        FCPS
#       </a>
#      </div>
#     </nav>
#     <div class="header">
#      <header class="header__content-wrapper" role="banner">
#       <div class="header__content fcps-color--bg-light2">
#        <div class="block block--search remodal" data-remodal-id="modal-search">
#         <div class="block__content">
#          <button class="remodal-close" data-remodal-action="close">
#          </button>
#          <div class="search">
#           <h4 class="search__title">
#            Search FCPS
#           </h4>
#           <form action="/search" class="search__form" method="get">
#            <div class="form-item search__text">
#             <input class="form-text" name="keywords" placeholder="Enter search terms" size="30" type="search"/>
#            </div>
#            <input class="button" type="submit" value="Search"/>
#            <button class="button button--secondary" data-remodal-action="cancel">
#             Cancel
#            </button>
#           </form>
#          </div>
#         </div>
#        </div>
#        <div class="header__utility">
#         <ul class="nav nav--utility-menu">
#          <li class="nav__item">
#           <a class="nav__link nav__link--language" data-remodal-target="modal-language-switcher" href="#" title="Translate this page">
#            <span>
#             <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle; background-repeat:no-repeat;background-position:-0px -0px; border:0;" width="16"/>
#             <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-0px -100px; border:0;" width="16"/>
#             <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-200px -100px; border:0;" width="16"/>
#             <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-300px -100px; border:0;" width="16"/>
#             <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-600px -100px; border:0;" width="16"/>
#             <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-300px -200px; border:0;" width="16"/>
#             <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-500px -200px; border:0;" width="16"/>
#             <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-600px -200px; border:0;" width="16"/>
#             Language
#            </span>
#           </a>
#          </li>
#          <li class="nav__item">
#           <a class="nav__link nav__link--search" data-remodal-target="modal-search" href="#">
#            Search
#           </a>
#          </li>
#          <li class="nav__item alerts-nav" id="alerts-nav">
#           <a class="nav__link nav__link--alert" href="/alerts">
#            Alerts
#           </a>
#          </li>
#         </ul>
#        </div>
#        <nav class="block block--menu-block" role="navigation">
#         <h2 class="element-invisible block__title">
#          Main Menu
#         </h2>
#         <ul class="nav nav--main-menu">
#          <li class="nav__item">
#           <a class="nav__link nav__full-menu-link" href="#fullmenu">
#            Full Menu
#           </a>
#          </li>
#          <li class="nav__item">
#           <a class="nav__link" data-drupal-link-system-path="node/299" href="/about">
#            About
#           </a>
#          </li>
#          <li class="nav__item nav__item--active-trail">
#           <a class="nav__link is-active" data-drupal-link-system-path="node/323" href="/academics">
#            Academics
#           </a>
#          </li>
#          <li class="nav__item">
#           <a class="nav__link" data-drupal-link-system-path="node/322" href="/activities">
#            Activities
#           </a>
#          </li>
#          <li class="nav__item">
#           <a class="nav__link" data-drupal-link-system-path="node/356" href="/resources">
#            Resources
#           </a>
#          </li>
#          <li class="nav__item">
#           <a class="nav__link" data-drupal-link-system-path="node/883" href="/contact">
#            Contact
#           </a>
#          </li>
#         </ul>
#        </nav>
#        <div class="header__logos">
#         <div class="header__logos-inner">
#          <a class="school-name" href="/" rel="home">
#           <span>
#            Thomas Jefferson High School for Science and Technology
#           </span>
#           <img alt="Home" src="/sites/default/files/TJ%20LogoTransparent.png"/>
#          </a>
#          <div class="site-name">
#           <a class="site-name__link" href="https://www.fcps.edu">
#            <h1 class="site-name__text">
#             FCPS
#            </h1>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="language-switcher-language-url block block--language-switcher remodal" data-remodal-id="modal-language-switcher" id="block-language-switcher" role="navigation">
#         <div class="block__content">
#          <button class="remodal-close" data-remodal-action="close">
#          </button>
#          <div class="gtranslate">
#           <script>
#            eval(unescape("eval%28function%28p%2Ca%2Cc%2Ck%2Ce%2Cr%29%7Be%3Dfunction%28c%29%7Breturn%28c%3Ca%3F%27%27%3Ae%28parseInt%28c/a%29%29%29+%28%28c%3Dc%25a%29%3E35%3FString.fromCharCode%28c+29%29%3Ac.toString%2836%29%29%7D%3Bif%28%21%27%27.replace%28/%5E/%2CString%29%29%7Bwhile%28c--%29r%5Be%28c%29%5D%3Dk%5Bc%5D%7C%7Ce%28c%29%3Bk%3D%5Bfunction%28e%29%7Breturn%20r%5Be%5D%7D%5D%3Be%3Dfunction%28%29%7Breturn%27%5C%5Cw+%27%7D%3Bc%3D1%7D%3Bwhile%28c--%29if%28k%5Bc%5D%29p%3Dp.replace%28new%20RegExp%28%27%5C%5Cb%27+e%28c%29+%27%5C%5Cb%27%2C%27g%27%29%2Ck%5Bc%5D%29%3Breturn%20p%7D%28%276%207%28a%2Cb%29%7Bn%7B4%282.9%29%7B3%20c%3D2.9%28%22o%22%29%3Bc.p%28b%2Cf%2Cf%29%3Ba.q%28c%29%7Dg%7B3%20c%3D2.r%28%29%3Ba.s%28%5C%27t%5C%27+b%2Cc%29%7D%7Du%28e%29%7B%7D%7D6%20h%28a%29%7B4%28a.8%29a%3Da.8%3B4%28a%3D%3D%5C%27%5C%27%29v%3B3%20b%3Da.w%28%5C%27%7C%5C%27%29%5B1%5D%3B3%20c%3B3%20d%3D2.x%28%5C%27y%5C%27%29%3Bz%283%20i%3D0%3Bi%3Cd.5%3Bi++%294%28d%5Bi%5D.A%3D%3D%5C%27B-C-D%5C%27%29c%3Dd%5Bi%5D%3B4%282.j%28%5C%27k%5C%27%29%3D%3DE%7C%7C2.j%28%5C%27k%5C%27%29.l.5%3D%3D0%7C%7Cc.5%3D%3D0%7C%7Cc.l.5%3D%3D0%29%7BF%286%28%29%7Bh%28a%29%7D%2CG%29%7Dg%7Bc.8%3Db%3B7%28c%2C%5C%27m%5C%27%29%3B7%28c%2C%5C%27m%5C%27%29%7D%7D%27%2C43%2C43%2C%27%7C%7Cdocument%7Cvar%7Cif%7Clength%7Cfunction%7CGTranslateFireEvent%7Cvalue%7CcreateEvent%7C%7C%7C%7C%7C%7Ctrue%7Celse%7CdoGTranslate%7C%7CgetElementById%7Cgoogle_translate_element2%7CinnerHTML%7Cchange%7Ctry%7CHTMLEvents%7CinitEvent%7CdispatchEvent%7CcreateEventObject%7CfireEvent%7Con%7Ccatch%7Creturn%7Csplit%7CgetElementsByTagName%7Cselect%7Cfor%7CclassName%7Cgoog%7Cte%7Ccombo%7Cnull%7CsetTimeout%7C500%27.split%28%27%7C%27%29%2C0%2C%7B%7D%29%29"))
#           </script>
#           <style>
#            #goog-gt-tt {display:none !important;}
#
# .goog-te-banner-frame {display:none !important;}
#
# .goog-te-menu-value:hover {text-decoration:none !important;}
#
# body {top:0 !important;}
#
# #google_translate_element2 {display:none!important;}
#           </style>
#           <div id="google_translate_element2">
#           </div>
#           <script>
#            function googleTranslateElementInit2() {new google.translate.TranslateElement({pageLanguage: 'en', autoDisplay: false}, 'google_translate_element2');}
#           </script>
#           <script src="https://translate.google.com/translate_a/element.js?cb=googleTranslateElementInit2">
#           </script>
#           <style>
#            a.gtflag {background-image:url('/modules/contrib/gtranslate/gtranslate-files/16a.png');}
# a.gtflag:hover {background-image:url('/modules/contrib/gtranslate/gtranslate-files/16.png');}
#           </style>
#           <a class="gtflag" href="javascript:doGTranslate('en|en')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-0px -0px;" title="English">
#            <img alt="English" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/>
#           </a>
#           <a class="gtflag" href="javascript:doGTranslate('en|nl')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-0px -100px;" title="Dutch">
#            <img alt="Dutch" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/>
#           </a>
#           <a class="gtflag" href="javascript:doGTranslate('en|fr')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-200px -100px;" title="French">
#            <img alt="French" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/>
#           </a>
#           <a class="gtflag" href="javascript:doGTranslate('en|de')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-300px -100px;" title="German">
#            <img alt="German" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/>
#           </a>
#           <a class="gtflag" href="javascript:doGTranslate('en|it')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-600px -100px;" title="Italian">
#            <img alt="Italian" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/>
#           </a>
#           <a class="gtflag" href="javascript:doGTranslate('en|pt')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-300px -200px;" title="Portuguese">
#            <img alt="Portuguese" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/>
#           </a>
#           <a class="gtflag" href="javascript:doGTranslate('en|ru')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-500px -200px;" title="Russian">
#            <img alt="Russian" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/>
#           </a>
#           <a class="gtflag" href="javascript:doGTranslate('en|es')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-600px -200px;" title="Spanish">
#            <img alt="Spanish" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/>
#           </a>
#           <br/>
#           <select aria-label="Website Language Selector" class="notranslate" id="gtranslate_selector" onchange="doGTranslate(this);">
#            <option value="">
#             Select Language
#            </option>
#            <option style="font-weight:bold;background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -0px;padding-left:18px;" value="en|en">
#             English
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -688px;padding-left:18px;" value="en|af">
#             Afrikaans
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -560px;padding-left:18px;" value="en|sq">
#             Albanian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1456px;padding-left:18px;" value="en|am">
#             Amharic
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -16px;padding-left:18px;" value="en|ar">
#             Arabic
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -832px;padding-left:18px;" value="en|hy">
#             Armenian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -848px;padding-left:18px;" value="en|az">
#             Azerbaijani
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -864px;padding-left:18px;" value="en|eu">
#             Basque
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -768px;padding-left:18px;" value="en|be">
#             Belarusian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -928px;padding-left:18px;" value="en|bn">
#             Bengali
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -944px;padding-left:18px;" value="en|bs">
#             Bosnian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -32px;padding-left:18px;" value="en|bg">
#             Bulgarian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -384px;padding-left:18px;" value="en|ca">
#             Catalan
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -960px;padding-left:18px;" value="en|ceb">
#             Cebuano
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -48px;padding-left:18px;" value="en|zh-CN">
#             Chinese (Simplified)
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -64px;padding-left:18px;" value="en|zh-TW">
#             Chinese (Traditional)
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -80px;padding-left:18px;" value="en|hr">
#             Croatian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -96px;padding-left:18px;" value="en|cs">
#             Czech
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -112px;padding-left:18px;" value="en|da">
#             Danish
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -128px;padding-left:18px;" value="en|nl">
#             Dutch
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -976px;padding-left:18px;" value="en|eo">
#             Esperanto
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -576px;padding-left:18px;" value="en|et">
#             Estonian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -400px;padding-left:18px;" value="en|tl">
#             Filipino
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -144px;padding-left:18px;" value="en|fi">
#             Finnish
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -160px;padding-left:18px;" value="en|fr">
#             French
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -592px;padding-left:18px;" value="en|gl">
#             Galician
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -880px;padding-left:18px;" value="en|ka">
#             Georgian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -176px;padding-left:18px;" value="en|de">
#             German
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -192px;padding-left:18px;" value="en|el">
#             Greek
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -992px;padding-left:18px;" value="en|gu">
#             Gujarati
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -896px;padding-left:18px;" value="en|ht">
#             Haitian Creole
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1008px;padding-left:18px;" value="en|ha">
#             Hausa
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -416px;padding-left:18px;" value="en|iw">
#             Hebrew
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -208px;padding-left:18px;" value="en|hi">
#             Hindi
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1024px;padding-left:18px;" value="en|hmn">
#             Hmong
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -608px;padding-left:18px;" value="en|hu">
#             Hungarian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -784px;padding-left:18px;" value="en|is">
#             Icelandic
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1040px;padding-left:18px;" value="en|ig">
#             Igbo
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -432px;padding-left:18px;" value="en|id">
#             Indonesian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -736px;padding-left:18px;" value="en|ga">
#             Irish
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -224px;padding-left:18px;" value="en|it">
#             Italian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -240px;padding-left:18px;" value="en|ja">
#             Japanese
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1056px;padding-left:18px;" value="en|jw">
#             Javanese
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1072px;padding-left:18px;" value="en|kn">
#             Kannada
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1088px;padding-left:18px;" value="en|km">
#             Khmer
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -256px;padding-left:18px;" value="en|ko">
#             Korean
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1104px;padding-left:18px;" value="en|lo">
#             Lao
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1120px;padding-left:18px;" value="en|la">
#             Latin
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -448px;padding-left:18px;" value="en|lv">
#             Latvian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -464px;padding-left:18px;" value="en|lt">
#             Lithuanian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -800px;padding-left:18px;" value="en|mk">
#             Macedonian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -704px;padding-left:18px;" value="en|ms">
#             Malay
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -624px;padding-left:18px;" value="en|mt">
#             Maltese
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1136px;padding-left:18px;" value="en|mi">
#             Maori
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1152px;padding-left:18px;" value="en|mr">
#             Marathi
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1168px;padding-left:18px;" value="en|mn">
#             Mongolian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1184px;padding-left:18px;" value="en|ne">
#             Nepali
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -272px;padding-left:18px;" value="en|no">
#             Norwegian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -672px;padding-left:18px;" value="en|fa">
#             Persian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -288px;padding-left:18px;" value="en|pl">
#             Polish
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -304px;padding-left:18px;" value="en|pt">
#             Portuguese
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1200px;padding-left:18px;" value="en|pa">
#             Punjabi
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -320px;padding-left:18px;" value="en|ro">
#             Romanian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -336px;padding-left:18px;" value="en|ru">
#             Russian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -480px;padding-left:18px;" value="en|sr">
#             Serbian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -496px;padding-left:18px;" value="en|sk">
#             Slovak
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -512px;padding-left:18px;" value="en|sl">
#             Slovenian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1216px;padding-left:18px;" value="en|so">
#             Somali
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -352px;padding-left:18px;" value="en|es">
#             Spanish
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -720px;padding-left:18px;" value="en|sw">
#             Swahili
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -368px;padding-left:18px;" value="en|sv">
#             Swedish
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1232px;padding-left:18px;" value="en|ta">
#             Tamil
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1248px;padding-left:18px;" value="en|te">
#             Telugu
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -640px;padding-left:18px;" value="en|th">
#             Thai
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -656px;padding-left:18px;" value="en|tr">
#             Turkish
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -528px;padding-left:18px;" value="en|uk">
#             Ukrainian
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -912px;padding-left:18px;" value="en|ur">
#             Urdu
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -544px;padding-left:18px;" value="en|vi">
#             Vietnamese
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -752px;padding-left:18px;" value="en|cy">
#             Welsh
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -816px;padding-left:18px;" value="en|yi">
#             Yiddish
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1264px;padding-left:18px;" value="en|yo">
#             Yoruba
#            </option>
#            <option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1280px;padding-left:18px;" value="en|zu">
#             Zulu
#            </option>
#           </select>
#          </div>
#          <button class="button button--secondary" data-remodal-action="cancel">
#           Close
#          </button>
#         </div>
#        </div>
#       </div>
#      </header>
#     </div>
#     <div class="region region-breadcrumb">
#      <nav aria-labelledby="block-footermenu-menu" id="block-footermenu" role="navigation">
#       <h2 class="visually-hidden" id="block-footermenu-menu">
#        Footer Menu
#       </h2>
#       <ul class="nav nav--footer-menu">
#        <li class="nav__item">
# ...
#               <div aria-label="photo of clock with trigonometry functions as hours" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Academics-Math_2.jpg?h=e0d9a4bb&amp;itok=6gRheqnb');">
#               </div>
#               <div class="node__content">
#                <h2 class="node__title">
#                 Mathematics
#                </h2>
#                <div class="node__summary">
#                 The mathematics curriculum is a comprehensive program, which includes the study of statistics, algebra, geometry, topics in discrete mathematics, trigonometry, functions, and calculus.
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="view__row">
#              <a class="node node--type-basic-page node--display-mode-card" href="/academics/mentorship" role="article">
#               <div aria-label="photo of upstairs hallway" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Upstairs%20Hallway.jpg?h=e2bcc475&amp;itok=hnBXZKRq');">
#               </div>
#               <div class="node__content">
#                <h2 class="node__title">
#                 <span>
#                  Mentorship
#                 </span>
#                </h2>
#                <div class="node__summary">
#                 The mentorship program permits students to test their interests and apply their knowledge and aptitude in a real-life setting, working with professionals who have chosen to share their insights and expertise.
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="view__row">
#              <a class="node node--type-section-page node--display-mode-card" href="/academics/pe-health-driver-education" role="article">
#               <div aria-label="photo of wall with figures playing sports" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Academics%20-%20PE_0.jpg?h=e0d9a4bb&amp;itok=mMkltxeY');">
#               </div>
#               <div class="node__content">
#                <h2 class="node__title">
#                 PE, Health, and Driver Education
#                </h2>
#                <div class="node__summary">
#                 The two-year physical education and health program emphasizes health and physical fitness, as well as individual and team sports.
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="view__row">
#              <a class="node node--type-section-page node--display-mode-card" href="/academics/research-program" role="article">
#               <div aria-label="photo of microscope" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Research%20Program_2.jpg?h=e0d9a4bb&amp;itok=UEGaPF3Q');">
#               </div>
#               <div class="node__content">
#                <h2 class="node__title">
#                 Research Program at TJ
#                </h2>
#                <div class="node__summary">
#                 Our unique research program consists of specialized research laboratories, a mentorship program, and tjSTAR.
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="view__row">
#              <a class="node node--type-section-page node--display-mode-card" href="/academics/science-and-technology" role="article">
#               <div aria-label="photo of students doing science experiement" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Academics-SciTech_0.jpg?h=d320664f&amp;itok=7VmyoN8W');">
#               </div>
#               <div class="node__content">
#                <h2 class="node__title">
#                 Science and Technology
#                </h2>
#                <div class="node__summary">
#                 Each student will complete four years of laboratory science beginning with Biology (integrated with English as well as Design and Technology) followed by Chemistry, Physics, and Geosystems.
#                </div>
#               </div>
#              </a>
#             </div>
#             <div class="view__row">
#              <a class="node node--type-section-page node--display-mode-card" href="/academics/world-languages" role="article">
#               <div aria-label="photo of globe and language dictionaries" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Academics%20-%20World%20Languages%20Main%20New.jpg?h=e0d9a4bb&amp;itok=vR9dEnBQ');">
#               </div>
#               <div class="node__content">
#                <h2 class="node__title">
#                 World Languages
#                </h2>
#                <div class="node__summary">
#                 The World Languages Department goal is to develop oral proficiency in the modern languages while instilling an awareness and appreciation of the cultures.
#                </div>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </section>
#         <div class="layout-constrain--narrow">
#          <section class="section section--callout fcps-color--bg-light2">
#           <div class="section__text">
#            <h3>
#             FCPSon
#            </h3>
#           </div>
#           <div class="">
#            <a class="button" href="https://www.fcps.edu/resources/technology/fcpson" target="_blank">
#             Learn about the one-to-one laptop program
#            </a>
#           </div>
#          </section>
#         </div>
#         <div class="layout-constrain--narrow">
#          <section class="section section--callout fcps-color--bg-light2">
#           <div class="section__text">
#            <h3>
#            </h3>
#           </div>
#           <div class="">
#            <a class="button" href="https://www.fcps.edu/academics/grading-and-reporting" target="_blank">
#             Learn about FCPS Grading and Reporting
#            </a>
#           </div>
#          </section>
#         </div>
#         <div class="views-element-container">
#         </div>
#        </div>
#       </article>
#      </div>
#     </main>
#     <footer class="footer" role="contentinfo">
#      <div class="region region-footer">
#       <div class="button-bar">
#        <div class="button-bar__content">
#         Stay updated with what's happening at Thomas Jefferson High School for Science and Technology with
#         <em>
#          News You Choose
#         </em>
#         <a class="button button--orange" href="https://public.govdelivery.com/accounts/VAEDUFCPS/subscriber/topics?qsp=Jefferson_HS">
#          Sign Up Now
#         </a>
#        </div>
#       </div>
#       <ul class="nav nav--footer-menu">
#        <li class="nav__item">
#         <a class="nav__link" href="https://lms.fcps.edu/" title="Schoology">
#          Schoology
#         </a>
#        </li>
#        <li class="nav__item">
#         <a class="nav__link" href="https://www.fcps.edu/student-information-system-sis">
#          SIS
#         </a>
#        </li>
#        <li class="nav__item">
#         <a class="nav__link" href="http://www.fcpsschools.net/" title="Google Workspace">
#          Google Workspace
#         </a>
#        </li>
#        <li class="nav__item">
#         <a class="nav__link" data-drupal-link-system-path="node/1559" href="/library">
#          Library
#         </a>
#        </li>
#        <li class="nav__item">
#         <a class="nav__link" href="http://fcps.nutrislice.com/">
#          Lunch Menus
#         </a>
#        </li>
#        <li class="nav__item">
#         <a class="nav__link" href="https://www.myschoolbucks.com/">
#          MySchoolBucks
#         </a>
#        </li>
#        <li class="nav__item">
#         <a class="nav__link" href="https://www.fcps.edu/careers/employee-resources">
#          Employee Resources
#         </a>
#        </li>
#       </ul>
#       <ul class="action-grid">
#        <li class="action-grid__item">
#         <a class="action-grid__link" href="/about/bell-schedules">
#          <img alt="an icon of a school bell" height="91" loading="lazy" src="/sites/default/files/media/promo/icon-bell.png" width="81"/>
#          <div class="action-grid__item-description">
#          </div>
#          <div class="action-grid__action">
#           Bell Schedule
#          </div>
#         </a>
#        </li>
#        <li class="action-grid__item">
#         <a class="action-grid__link" href="/library">
#          <img alt="an icon of a book" height="91" loading="lazy" src="/sites/default/files/media/promo/icon-book-yellow.png" width="66"/>
#          <div class="action-grid__item-description">
#          </div>
#          <div class="action-grid__action">
#           Library
#          </div>
#         </a>
#        </li>
#        <li class="action-grid__item">
#         <a class="action-grid__link" href="http://fcps.nutrislice.com/menu/thomas-jefferson-high-school/hs-lunch/">
#          <img alt="icon of food" height="91" loading="lazy" src="/sites/default/files/media/promo/icon-lunch.png" width="110"/>
#          <div class="action-grid__item-description">
#          </div>
#          <div class="action-grid__action">
#           Lunch Menu
#          </div>
#         </a>
#        </li>
#        <li class="action-grid__item">
#         <a class="action-grid__link" href="/contact">
#          <img alt="an icon of an envelope" height="91" loading="lazy" src="/sites/default/files/media/promo/icon-contact.png" width="93"/>
#          <div class="action-grid__item-description">
#          </div>
#          <div class="action-grid__action">
#           Contact Us
#          </div>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="footer-meta">
#       <div class="footer-meta__school fcps-color--bg-light2">
#        <div class="layout-constrain">
#         <div class="footer-meta__school-inner">
#          <div class="footer-meta__school-info">
#           <a href="https://www.google.com/maps/place/6560+Braddock+Rd%0D%0AAlexandria+VA+22312" target="_blank">
#            <img alt="Home" src="/sites/default/files/TJ%20LogoTransparent.png"/>
#            <span>
#             Thomas Jefferson High School for Science and Technology
#             <address>
#              6560 Braddock Rd
# Alexandria VA 22312
#             </address>
#            </span>
#           </a>
#          </div>
#          <div class="footer-meta__school-contact">
#           <div>
#            <strong>
#             Main Office
#            </strong>
#           </div>
#           <div>
#            <a href="tel:703-750-8300">
#             703-750-8300
#            </a>
#           </div>
#           <div>
#            8:00 a.m. - 4:15 p.m.
#           </div>
#          </div>
#          <div class="footer-meta__school-contact">
#           <div>
#            <strong>
#             Attendance
#            </strong>
#           </div>
#           <div>
#            <a href="tel:703-750-8315 ">
#             703-750-8315
#            </a>
#           </div>
#           <div>
#            <a href="/cdn-cgi/l/email-protection#33675b5c5e5240795655555641405c5d7b5a545b1d724747565d57525d505673555043401d565746">
#             <span class="__cf_email__" data-cfemail="1f4b7770727e6c557a79797a6d6c707157767877315e6b6b7a717b7e717c7a5f797c6f6c317a7b6a">
#              [email protected]
#             </span>
#            </a>
#           </div>
#           <div>
#            <p>
#             <a href="/about/attendance">
#              Attendance Procedures
#             </a>
#            </p>
#           </div>
#          </div>
#          <div class="footer-meta__school-contact">
#           <div>
#            <strong>
#             Principal
#            </strong>
#           </div>
#           <div>
#            Ann Bonitatibus
#           </div>
#           <div>
#            <a data-mail-to="naobavgngvoh/ng/spcf/qbg/rqh" data-replace-inner="" href="#" target="_blank">
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="footer-meta__social fcps-color--bg-dark1">
#        <ul class="social-links">
#         <li>
#          <a class="social-links__twitter" href="https://twitter.com/TJAnnB" target="_blank">
#           Twitter
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="footer-meta__logo">
#        <a class="footer-meta__logo-link" href="https://www.fcps.edu">
#         Fairfax County Public Schools
#        </a>
#       </div>
#       <ul class="footer-meta__links">
#        <li>
#         <a href="https://www.fcps.edu/about-fcps/policies-regulations-and-notices/web-accessibility-guidelines">
#          Web Accessibility Guidelines
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fcps.edu/about-fcps/policies-regulations-and-notices/virginia-freedom-information-act-vfoia">
#          Freedom of Information Act
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fcps.edu/about-fcps/policies-regulations-and-notices">
#          Policies and Regulations
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fcps.edu/about-fcps/policies-regulations-and-notices/web-privacy-policy">
#          Web Privacy Policy
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fcps.edu/nondiscrimination">
#          Nondiscrimination
#         </a>
#        </li>
#       </ul>
#       <div class="footer-meta__copyright">
#        © 2022 Fairfax County Public Schools, Fairfax County, Virginia
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#   <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#   </script>
#   <script data-drupal-selector="drupal-settings-json" type="application/json">
#    {"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"node\/323","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"back_to_top":{"back_to_top_button_trigger":"100","back_to_top_prevent_on_mobile":0,"back_to_top_prevent_in_admin":0,"back_to_top_button_type":"image","back_to_top_button_text":"Back to top"},"data":{"extlink":{"extTarget":true,"extTargetNoOverride":false,"extNofollow":true,"extNoreferrer":false,"extFollowNoOverride":false,"extClass":"ext","extLabel":"(link is external)","extImgClass":false,"extSubdomains":false,"extExclude":"","extInclude":"","extCssExclude":"","extCssExplicit":"main","extAlert":false,"extAlertText":"This link will take you to an external web site. We are not responsible for their content.","mailtoClass":"mailto","mailtoLabel":"(link sends email)","extUseFontAwesome":false,"extIconPlacement":"append","extFaLinkClasses":"fa fa-external-link","extFaMailtoClasses":"fa fa-envelope-o","whitelistedDomains":null}},"fcps_site":{"menu":{"title":"TJHSST"}},"facility_id":"2300","alerts_target_url":"https:\/\/www.fcps.edu","user":{"uid":0,"permissionsHash":"3c063834cd7d9b66cb3808ecbf16a721ec0e05883d3472f2619f3340cfc1e1cb"}}
#   </script>
#   <script src="/sites/default/files/js/js_Se3GPboWxub0W9h6A2zhgvoWWf2zf1onALy2P8SDjQc.js">
#   </script>
#   <script src="//addevent.com/libs/atc/1.6.1/atc.min.js">
#   </script>
#   <script src="/sites/default/files/js/js_Qzn2IxD_JJvxdF7AjTZRj1s6EaCeJgLol-al2daelqs.js">
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"869a1a293e","applicationID":"71440368","transactionName":"ZwEAY0BXXUZZBREKDV5LI1RGX1xbFxYEBAdvBwNUWlM=","queueTime":0,"applicationTime":23,"atts":"S0YDFQhNTkg=","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#   <script crossorigin="anonymous" data-cf-beacon='{"rayId":"6dbfa490ec48f060","token":"39dceb23f25b43b58ac8cd81068dccfa","version":"2021.12.0","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194">
#   </script>
#  </body>
# </html>

# %%
list(soup.children)
# Out:
# ['\n',
#  'html',
#  '\n',
#  '[if lt IE 7]>      <html class="ie6 lt-ie9 lt-ie8 lt-ie7 no-js" lang="en" dir="ltr"> <![endif]',
#  '\n',
#  '[if IE 7]>         <html class="ie7 lt-ie9 lt-ie8 no-js" lang="en" dir="ltr"> <![endif]',
#  '\n',
#  '[if IE 8]>         <html class="ie8 lt-ie9 no-js" lang="en" dir="ltr"> <![endif]',
#  '\n',
#  '[if IE 9]>         <html class="ie9 no-js" lang="en" dir="ltr"> <![endif]',
#  '\n',
#  '[if gt IE 9]><!',
#  ' ',
#  <html class="no-js" dir="ltr" lang="en"> <!--<![endif]-->
#  <head>
#  <meta charset="utf-8"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"869a1a293e",applicationID:"71440368"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n,r){return function(){return s.recordSupportability("API/"+e+"/called"),o(t+e,[u.now()].concat(c(arguments)),n?null:this,r),n?void 0:this}}var o=t("handle"),a=t(10),c=t(11),f=t("ee").get("tracer"),u=t("loader"),s=t(4),d=NREUM;"undefined"==typeof window.newrelic&&(newrelic=d);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",v=l+"ixn-";a(p,function(t,e){d[e]=i(l,e,!0,"api")}),d.addPageAction=i(l,"addPageAction",!0),d.setCurrentRouteName=i(l,"routeName",!0),e.exports=newrelic,d.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(v+"tracer",[u.now(),t,n],r),function(){if(f.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw f.emit("fn-err",[arguments,this,t],n),t}finally{f.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(v,e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),s.recordSupportability("API/noticeError/called"),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){var r=!1;try{var i=Object.defineProperty({},"passive",{get:function(){r=!0}});window.addEventListener("testPassive",null,i),window.removeEventListener("testPassive",null,i)}catch(o){}e.exports=function(t){return r?{passive:!0,capture:!!t}:!!t}},{}],4:[function(t,e,n){function r(t,e){var n=[a,t,{name:t},e];return o("storeMetric",n,null,"api"),n}function i(t,e){var n=[c,t,{name:t},e];return o("storeEventMetrics",n,null,"api"),n}var o=t("handle"),a="sm",c="cm";e.exports={constants:{SUPPORTABILITY_METRIC:a,CUSTOM_METRIC:c},recordSupportability:r,recordCustom:i}},{}],5:[function(t,e,n){function r(){return c.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,c=t(12);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],6:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],7:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?l("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&l("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();if(n.length>0){var r=n[n.length-1];if(u&&u<r.startTime)return;var i=[r],o=a({});o&&i.push(o),l("lcp",i)}}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||l("cls",[t])})}function a(t){var e=navigator.connection||navigator.mozConnection||navigator.webkitConnection;if(e)return e.type&&(t["net-type"]=e.type),e.effectiveType&&(t["net-etype"]=e.effectiveType),e.rtt&&(t["net-rtt"]=e.rtt),e.downlink&&(t["net-dlink"]=e.downlink),t}function c(t){if(t instanceof y&&!w){var e=Math.round(t.timeStamp),n={type:t.type};a(n),e<=v.now()?n.fid=v.now()-e:e>v.offset&&e<=Date.now()?(e-=v.offset,n.fid=v.now()-e):e=v.now(),w=!0,l("timing",["fi",e,n])}}function f(t){"hidden"===t&&(u=v.now(),l("pageHide",[u]))}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing. ...
#  <noscript><style>form.antibot * :not(.antibot-message) { display: none !important; }</style>
#  </noscript><link href="/sites/default/files/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#  <link href="/sites/default/files/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#  <link href="/sites/default/files/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#  <link href="/sites/default/files/favicons/site.webmanifest" rel="manifest"/>
#  <link color="#5bbad5" href="/sites/default/files/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#  <meta content="#da532c" name="msapplication-TileColor"/>
#  <meta content="#ffffff" name="theme-color"/>
#  <meta content="Drupal responsive_favicons + realfavicongenerator.net" name="favicon-generator"/>
#  <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
#  <meta content="width" name="MobileOptimized"/>
#  <meta content="true" name="HandheldFriendly"/>
#  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#  <link href="https://tjhsst.fcps.edu/academics" rel="canonical"/>
#  <link href="https://tjhsst.fcps.edu/node/323" rel="shortlink"/>
#  <link href="https://tjhsst.fcps.edu/academics" rel="revision"/>
#  <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0];var j=d.createElement(s);var dl=l!='dataLayer'?'&l='+l:'';j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl+'';j.async=true;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-NDP35T');</script>
#  <title>Academics | Thomas Jefferson High School for Science and Technology</title>
#  <link href="/sites/default/files/css/css_F2gAVVlSdR3arDUpXp31o79SNgjcEodwd2bnXsnktzU.css" media="all" rel="stylesheet"/>
#  <link href="/sites/default/files/css/css_qLLa0fjxzXjbti0Orln7hrTaNyPa4k-xxnc6qhu8ET4.css" media="all" rel="stylesheet"/>
#  <link href="//addtocalendar.com/atc/1.5/atc-style-menu-wb.css" media="all" rel="stylesheet"/>
#  <link href="//fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,700,700italic|Arimo:400,400italic,700,700italic" media="all" rel="stylesheet"/>
#  <!--[if gte IE 9]><!-->
#  <link href="/sites/default/files/css/css_vJikm4_bcHTyPthFqjhMXbEYuxmXu-DDEs1qvUcK9fM.css" media="all" rel="stylesheet"/>
#  <!--<![endif]-->
#  <link href="/sites/default/files/css/css_vzVKUq7TwP7gm4NwMDu1AHrGMjU4MkdjFlm4uwbW6ds.css" media="all" rel="stylesheet"/>
#  <script src="/core/assets/vendor/modernizr/modernizr.min.js?v=3.11.7"></script>
#  <script src="/core/misc/modernizr-additional-tests.js?v=3.11.7"></script>
#  </head>
#  <body class="path-node not-front page--node-type-landing-page fcps-dark-color-1 fcps-light-color-2">
#  <noscript aria-hidden="true"><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NDP35T" style="display:none;visibility:hidden" width="0"></iframe></noscript>
#  <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#  <div class="page-container remodal-bg">
#  <div class="skiplinks">
#  <a class="skiplinks__link element-focusable" href="#main">Skip to main content</a>
#  </div>
#  <nav class="block block--menu-block" id="fullmenu" role="navigation">
#  <h2 class="element-invisible block__title">Full Menu</h2>
#  <ul class="nav nav--full-menu">
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="&lt;front&gt;" href="/">Homepage</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/299" href="/about">About</a>
#  <ul class="nav nav--full-menu__subnav">
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/327" href="/about/administration">Administration</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1901" href="/about/attendance">Attendance</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/3802" href="/resources/challenge-success-program-tjhsst" title="Challenge Success Program at TJHSST">Challenge Success Program</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/2871" href="/about/bell-schedules">Bell Schedules</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" href="https://schoolprofiles.fcps.edu/schlprfl/f?p=108%3A50%3A%3A%3A%3A%3AP0_CURRENT_SCHOOL_ID%3A300" target="_blank">FCPS School Profile</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/5693" href="/esserIII-SIIP2021-22">School Innovation and Improvement Plan</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/851" href="/staff-directory">Staff Directory</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/3090" href="/about/tjhsst-honor-code">TJHSST Honor Code</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/3091" href="/about/tjhsst-student-advocacy">TJHSST Student Advocacy</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/3271" href="/about/transportation">Transportation</a>
#  </li>
#  </ul>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" href="https://www.fcps.edu/registration/thomas-jefferson-admissions" target="_blank">Admission</a>
#  </li>
#  <li class="nav__item nav__item--active-trail">
#  <a class="nav__link is-active" data-drupal-link-system-path="node/323" href="/academics">Academics</a>
#  <ul class="nav nav--full-menu__subnav">
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1938" href="/academics/computer-science">Computer Science</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1834" href="/academics/fine-arts">Fine Arts</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1905" href="/academics/humanities">Humanities</a>
#  <ul class="nav nav--full-menu__subnav">
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1836" href="/academics/humanities/english">English</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1837" href="/academics/humanities/social-studies">Social Studies</a>
#  </li>
#  </ul>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1940" href="/academics/mathematics">Mathematics</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1894" href="/academics/mentorship">Mentorship</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1936" href="/academics/pe-health-driver-education">PE, Health, Driver Education</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/2762" href="/academics/research-program">Research Program</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1941" href="/academics/science-and-technology">Science and Technology</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" href="https://insys.fcps.edu/CourseCatOnline/frontPanel/503/nocourselist/0/0/0/1" target="_blank">TJHSST Course Catalog</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1942" href="/academics/world-languages">World Languages</a>
#  </li>
#  </ul>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/144" href="/announcements">Announcements</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1221" href="/events">Events</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/284" href="/features">Features</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1573" href="/get-involved">Get Involved</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1559" href="/library">Library</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/356" href="/resources">Resources</a>
#  <ul class="nav nav--full-menu__subnav">
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/3802" href="/resources/challenge-success-program-tjhsst">Challenge Success Program at TJHSST</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/2042" href="/student-services/curricular-resources">Curricular Resources</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/4858" href="/adopteddigitalresources">Digital Resources at TJHSST - Parent Consent</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1899" href="/resources/health-room">Health Room</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/2535" href="/resources/student-wellness-resources">Student Wellness Resources</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1871" href="/resources/technology-resources">Technology Resources</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1944" href="/resources/additional-resources">Additional Resources</a>
#  </li>
#  </ul>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/851" href="/staff-directory">Staff Directory</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/322" href="/activities">Student Life and Activities</a>
#  <ul class="nav nav--full-menu__subnav">
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1985" href="/student-life-and-activities/8th-period-activities">8th Period Activities</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1898" href="/student-life-and-activities/athletics">Athletics</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1986" href="/student-life-and-activities/publications">Publications</a>
#  </li>
#  </ul>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/298" href="/student-services" title="Student Services">Student Services</a>
#  <ul class="nav nav--full-menu__subnav">
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1904" href="/student-services/college-and-career-center">College and Career Center</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/2042" href="/student-services/curricular-resources">Curricular Resources</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1945" href="/student-services/special-services">Special Services</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/5521" href="/testing">Testing</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/2031" href="/student-services/transcript-requests">Transcript Requests</a>
#  </li>
#  </ul>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/883" href="/contact">Contact</a>
#  </li>
#  </ul>
#  </nav>
#  <nav class="mobile-menu" role="navigation">
#  <div class="mobile-menu__bar">
#  <a class="mobile-menu__button js-mobile-menu-button mobile-menu__button--menu" href="#fullmenu"><span class="mobile-menu__icon mobile-menu__icon--menu"></span><span class="mobile-menu__text">Menu</span></a>
#  <a class="nav__link nav__link--alert" href="/alerts" id="alerts-nav-mobile"> <span class="mobile-alert-icon"> </span> <span class="mobile-alert-text">Alerts</span></a>
#  <a class="mobile-menu__school-name" href="/" rel="home"><span>Thomas Jefferson High School for Science and Technology</span><img alt="Home" src="/sites/default/files/TJ%20LogoTransparent.png"/></a>
#  <a class="mobile-menu__logo" href="/">FCPS</a>
#  </div>
#  </nav>
#  <div class="header">
#  <header class="header__content-wrapper" role="banner">
#  <div class="header__content fcps-color--bg-light2">
#  <div class="block block--search remodal" data-remodal-id="modal-search">
#  <div class="block__content">
#  <button class="remodal-close" data-remodal-action="close"></button>
#  <div class="search">
#  <h4 class="search__title">Search FCPS</h4>
#  <form action="/search" class="search__form" method="get">
#  <div class="form-item search__text">
#  <input class="form-text" name="keywords" placeholder="Enter search terms" size="30" type="search"/>
#  </div>
#  <input class="button" type="submit" value="Search"/>
#  <button class="button button--secondary" data-remodal-action="cancel">Cancel</button>
#  </form>
#  </div>
#  </div>
#  </div>
#  <div class="header__utility">
#  <ul class="nav nav--utility-menu">
#  <li class="nav__item"><a class="nav__link nav__link--language" data-remodal-target="modal-language-switcher" href="#" title="Translate this page"><span>
#  <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle; background-repeat:no-repeat;background-position:-0px -0px; border:0;" width="16"/>
#  <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-0px -100px; border:0;" width="16"/>
#  <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-200px -100px; border:0;" width="16"/>
#  <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-300px -100px; border:0;" width="16"/>
#  <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-600px -100px; border:0;" width="16"/>
#  <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-300px -200px; border:0;" width="16"/>
#  <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-500px -200px; border:0;" width="16"/>
#  <img alt="Translate" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="background-image: url(/modules/contrib/gtranslate/gtranslate-files/16.png); font-size:16px;vertical-align: middle;background-repeat:no-repeat;background-position:-600px -200px; border:0;" width="16"/>
#  Language</span></a></li>
#  <li class="nav__item"><a class="nav__link nav__link--search" data-remodal-target="modal-search" href="#">Search</a></li>
#  <li class="nav__item alerts-nav" id="alerts-nav"><a class="nav__link nav__link--alert" href="/alerts">Alerts</a></li>
#  </ul>
#  </div>
#  <nav class="block block--menu-block" role="navigation">
#  <h2 class="element-invisible block__title">Main Menu</h2>
#  <ul class="nav nav--main-menu">
#  <li class="nav__item">
#  <a class="nav__link nav__full-menu-link" href="#fullmenu">Full Menu</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/299" href="/about">About</a>
#  </li>
#  <li class="nav__item nav__item--active-trail">
#  <a class="nav__link is-active" data-drupal-link-system-path="node/323" href="/academics">Academics</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/322" href="/activities">Activities</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/356" href="/resources">Resources</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/883" href="/contact">Contact</a>
#  </li>
#  </ul>
#  </nav>
#  <div class="header__logos">
#  <div class="header__logos-inner">
#  <a class="school-name" href="/" rel="home"><span>Thomas Jefferson High School for Science and Technology</span><img alt="Home" src="/sites/default/files/TJ%20LogoTransparent.png"/></a>
#  <div class="site-name">
#  <a class="site-name__link" href="https://www.fcps.edu">
#  <h1 class="site-name__text">FCPS</h1>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="language-switcher-language-url block block--language-switcher remodal" data-remodal-id="modal-language-switcher" id="block-language-switcher" role="navigation">
#  <div class="block__content">
#  <button class="remodal-close" data-remodal-action="close"></button>
#  <div class="gtranslate">
#  <script>eval(unescape("eval%28function%28p%2Ca%2Cc%2Ck%2Ce%2Cr%29%7Be%3Dfunction%28c%29%7Breturn%28c%3Ca%3F%27%27%3Ae%28parseInt%28c/a%29%29%29+%28%28c%3Dc%25a%29%3E35%3FString.fromCharCode%28c+29%29%3Ac.toString%2836%29%29%7D%3Bif%28%21%27%27.replace%28/%5E/%2CString%29%29%7Bwhile%28c--%29r%5Be%28c%29%5D%3Dk%5Bc%5D%7C%7Ce%28c%29%3Bk%3D%5Bfunction%28e%29%7Breturn%20r%5Be%5D%7D%5D%3Be%3Dfunction%28%29%7Breturn%27%5C%5Cw+%27%7D%3Bc%3D1%7D%3Bwhile%28c--%29if%28k%5Bc%5D%29p%3Dp.replace%28new%20RegExp%28%27%5C%5Cb%27+e%28c%29+%27%5C%5Cb%27%2C%27g%27%29%2Ck%5Bc%5D%29%3Breturn%20p%7D%28%276%207%28a%2Cb%29%7Bn%7B4%282.9%29%7B3%20c%3D2.9%28%22o%22%29%3Bc.p%28b%2Cf%2Cf%29%3Ba.q%28c%29%7Dg%7B3%20c%3D2.r%28%29%3Ba.s%28%5C%27t%5C%27+b%2Cc%29%7D%7Du%28e%29%7B%7D%7D6%20h%28a%29%7B4%28a.8%29a%3Da.8%3B4%28a%3D%3D%5C%27%5C%27%29v%3B3%20b%3Da.w%28%5C%27%7C%5C%27%29%5B1%5D%3B3%20c%3B3%20d%3D2.x%28%5C%27y%5C%27%29%3Bz%283%20i%3D0%3Bi%3Cd.5%3Bi++%294%28d%5Bi%5D.A%3D%3D%5C%27B-C-D%5C%27%29c%3Dd%5Bi%5D%3B4%282.j%28%5C%27k%5C%27%29%3D%3DE%7C%7C2.j%28%5C%27k%5C%27%29.l.5%3D%3D0%7C%7Cc.5%3D%3D0%7C%7Cc.l.5%3D%3D0%29%7BF%286%28%29%7Bh%28a%29%7D%2CG%29%7Dg%7Bc.8%3Db%3B7%28c%2C%5C%27m%5C%27%29%3B7%28c%2C%5C%27m%5C%27%29%7D%7D%27%2C43%2C43%2C%27%7C%7Cdocument%7Cvar%7Cif%7Clength%7Cfunction%7CGTranslateFireEvent%7Cvalue%7CcreateEvent%7C%7C%7C%7C%7C%7Ctrue%7Celse%7CdoGTranslate%7C%7CgetElementById%7Cgoogle_translate_element2%7CinnerHTML%7Cchange%7Ctry%7CHTMLEvents%7CinitEvent%7CdispatchEvent%7CcreateEventObject%7CfireEvent%7Con%7Ccatch%7Creturn%7Csplit%7CgetElementsByTagName%7Cselect%7Cfor%7CclassName%7Cgoog%7Cte%7Ccombo%7Cnull%7CsetTimeout%7C500%27.split%28%27%7C%27%29%2C0%2C%7B%7D%29%29"))</script><style>
#  #goog-gt-tt {display:none !important;}
#
#  .goog-te-banner-frame {display:none !important;}
#
#  .goog-te-menu-value:hover {text-decoration:none !important;}
#
#  body {top:0 !important;}
#
#  #google_translate_element2 {display:none!important;}
#  </style><div id="google_translate_element2"></div>
#  <script>function googleTranslateElementInit2() {new google.translate.TranslateElement({pageLanguage: 'en', autoDisplay: false}, 'google_translate_element2');}</script>
#  <script src="https://translate.google.com/translate_a/element.js?cb=googleTranslateElementInit2"></script><style>
#  a.gtflag {background-image:url('/modules/contrib/gtranslate/gtranslate-files/16a.png');}
#  a.gtflag:hover {background-image:url('/modules/contrib/gtranslate/gtranslate-files/16.png');}
#  </style><a class="gtflag" href="javascript:doGTranslate('en|en')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-0px -0px;" title="English"><img alt="English" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/></a> <a class="gtflag" href="javascript:doGTranslate('en|nl')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-0px -100px;" title="Dutch"><img alt="Dutch" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/></a> <a class="gtflag" href="javascript:doGTranslate('en|fr')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-200px -100px;" title="French"><img alt="French" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/></a> <a class="gtflag" href="javascript:doGTranslate('en|de')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-300px -100px;" title="German"><img alt="German" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/></a> <a class="gtflag" href="javascript:doGTranslate('en|it')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-600px -100px;" title="Italian"><img alt="Italian" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/></a> <a class="gtflag" href="javascript:doGTranslate('en|pt')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-300px -200px;" title="Portuguese"><img alt="Portuguese" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/></a> <a class="gtflag" href="javascript:doGTranslate('en|ru')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-500px -200px;" title="Russian"><img alt="Russian" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/></a> <a class="gtflag" href="javascript:doGTranslate('en|es')" style="font-size:16px;padding:1px 0;background-repeat:no-repeat;background-position:-600px -200px;" title="Spanish"><img alt="Spanish" height="16" src="/modules/contrib/gtranslate/gtranslate-files/blank.png" style="border:0;vertical-align:top;" width="16"/></a> <br/><select aria-label="Website Language Selector" class="notranslate" id="gtranslate_selector" onchange="doGTranslate(this);"><option value="">Select Language</option><option style="font-weight:bold;background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -0px;padding-left:18px;" value="en|en">English</option><option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -688px;padding-left:18px;" value="en|af">Afrikaans</option><option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -560px;padding-left:18px;" value="en|sq">Albanian</option><option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -1456px;padding-left:18px;" value="en|am">Amharic</option><option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -16px;padding-left:18px;" value="en|ar">Arabic</option><option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -832px;padding-left:18px;" value="en|hy">Armenian</option><option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -848px;padding-left:18px;" value="en|az">Azerbaijani</option><option style="background:url('/modules/contrib/gtranslate/gtranslate-files/16l.png') no-repeat scroll 0 -864px;pa ...
#  </div>
#  <button class="button button--secondary" data-remodal-action="cancel">Close</button>
#  </div>
#  </div>
#  </div>
#  </header>
#  </div>
#  <div class="region region-breadcrumb">
#  <nav aria-labelledby="block-footermenu-menu" id="block-footermenu" role="navigation">
#  <h2 class="visually-hidden" id="block-footermenu-menu">Footer Menu</h2>
#  <ul class="nav nav--footer-menu">
#  <li class="nav__item">
#  <a class="nav__link" href="https://lms.fcps.edu/" title="Schoology">Schoology</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" href="https://www.fcps.edu/student-information-system-sis">SIS</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" href="http://www.fcpsschools.net/" title="Google Workspace">Google Workspace</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1559" href="/library">Library</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" href="http://fcps.nutrislice.com/">Lunch Menus</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" href="https://www.myschoolbucks.com/">MySchoolBucks</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" href="https://www.fcps.edu/careers/employee-resources">Employee Resources</a>
#  </li>
#  </ul>
#  </nav>
#  </div>
#  <div class="region region-highlighted">
#  <div class="hidden" data-drupal-messages-fallback=""></div>
#  </div>
#  <main class="main" id="main" role="main" tabindex="-1">
#  <div class="region region-content">
#  <article class="node node--type-landing-page node--display-mode-full" role="article">
#  <div class="node__content">
#  <section class="ssection section--superhero fcps-color--bg-dark1">
#  <div aria-label="photo of TJ logo" class="section__image" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/superhero/public/media/hero/Academics%20-%20main.jpg?h=bc816b12&amp;itok=xnMzCDyv');"></div>
#  <div class="section__text">
#  <div class="section__text-inner">
#  <h1 class="section__title">Academics</h1>
#  <div class="section__summary">Learn about our Curriculum, Departments, and more</div>
#  </div>
#  </div>
#  </section>
#  <section class="section section--text">
#  <div class="layout-constrain--narrow">
#  <h2>Curriculum Overview</h2>
#  <p>TJHSST provides a comprehensive curriculum, emphasizing the sciences, mathematics, and technology.</p>
#  <ul>
#  </ul>
#  <p>All seniors are required to complete a technology laboratory project as the culmination of their TJHSST academic experience, either in one of the specialized <a href="/research-program">Research Laboratories</a>, or through the <a href="/academics/mentorship">Mentorship Program</a>.</p>
#  <p>The TJHSST school day begins at 8:40 a.m. and ends at 4:00 p.m. Seven periods are devoted to academic coursework and one period is designated for <a href="/student-life-and-activities">student activities</a> and activity-related coursework. Student and faculty research is supported by the <a href="/library">Geoff Jones Library</a>. Many online resources are made available to students and staff, including Mathematica and numerous online databases.</p>
#  <p>The foundation of the curricular program at TJHSST focuses on an interdisciplinary approach aimed at maximizing the full potential of each student's intellectual, technological and affective skills. Course work such as the ninth grade <strong>IBET program</strong> and <a href="/academics/humanities">humanities</a> courses are driven by six learning methodologies:</p>
#  <ol>
#  <li>acquiring powerful communication skills</li>
#  <li>developing collaborative skills</li>
#  <li>thinking and working in the context of systems</li>
#  <li>working with real projects and problems</li>
#  <li>managing change</li>
#  <li>developing an ethical culture</li>
#  </ol>
#  <p>The following programs are unique to TJHSST and are among some of the specialized course work required of our students:</p>
#  <ul>
#  <li>IBET (Integrated Biology, English and Technology)</li>
#  <li><a href="/research-program">Research Program</a></li>
#  <li><a href="/academics/mentorship">Mentorship Program</a></li>
#  </ul>
#  <p> </p>
#  </div>
#  </section>
#  <div class="layout-constrain--narrow">
#  <section class="section section--callout fcps-color--bg-light2">
#  <div class="section__text">
#  <h3></h3>
#  </div>
#  <div class="">
#  <a class="button" href="https://insys.fcps.edu/CourseCatOnline/frontPanel/503/nocourselist/0/0/0/1">See the TJHSST Course Catalog</a>
#  </div>
#  </section>
#  </div>
#  <section class="section section--list">
#  <div class="view view--three-col view--bgcolor">
#  <div class="layout-constrain">
#  <div class="view__content">
#  <div class="view__row">
#  <a class="node node--type-section-page node--display-mode-card" href="/academics/computer-science" role="article">
#  <div aria-label="photo of keyboard and mouse" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Academics-CS.jpg?h=e0d9a4bb&amp;itok=B986J1O1');"></div>
#  <div class="node__content">
#  <h2 class="node__title">Computer Science</h2>
#  <div class="node__summary">Thomas Jefferson High School for Science and Technology offers six years of computer science. Our goal is to provide a world class computer science education to our students and to disseminate curriculum materials to other academic institutions.</div>
#  </div>
#  </a>
#  </div>
#  <div class="view__row">
#  <a class="node node--type-basic-page node--display-mode-card" href="/academics/fine-arts" role="article">
#  <div aria-label="photo of guitar art" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Academics%20-%20Fine%20Arts.jpg?h=e2bcc475&amp;itok=jgLMpziJ');"></div>
#  <div class="node__content">
#  <h2 class="node__title"><span>Fine Arts</span>
#  </h2>
#  <div class="node__summary">The Fine Arts department offers courses in performance and visual art. Students must fulfill a one credit fine arts requirement for graduation.</div>
#  </div>
#  </a>
#  </div>
#  <div class="view__row">
#  <a class="node node--type-section-page node--display-mode-card" href="/academics/humanities" role="article">
#  <div aria-label="photo of Virginia Gazette newspaper" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Academics%20-%20Humanities_0.jpg?h=f82465d7&amp;itok=wMjO5liF');"></div>
#  <div class="node__content">
#  <h2 class="node__title">Humanities (English and Social Studies)</h2>
#  <div class="node__summary">The Thomas Jefferson Humanities Division includes teachers of English and Social Studies.</div>
#  </div>
#  </a>
#  </div>
#  <div class="view__row">
#  <a class="node node--type-section-page node--display-mode-card" href="/academics/mathematics" role="article">
#  <div aria-label="photo of clock with trigonometry functions as hours" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Academics-Math_2.jpg?h=e0d9a4bb&amp;itok=6gRheqnb');"></div>
#  <div class="node__content">
#  <h2 class="node__title">Mathematics</h2>
#  <div class="node__summary">The mathematics curriculum is a comprehensive program, which includes the study of statistics, algebra, geometry, topics in discrete mathematics, trigonometry, functions, and calculus.</div>
#  </div>
#  </a>
#  </div>
#  <div class="view__row">
#  <a class="node node--type-basic-page node--display-mode-card" href="/academics/mentorship" role="article">
#  <div aria-label="photo of upstairs hallway" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Upstairs%20Hallway.jpg?h=e2bcc475&amp;itok=hnBXZKRq');"></div>
#  <div class="node__content">
#  <h2 class="node__title"><span>Mentorship</span>
#  </h2>
#  <div class="node__summary">The mentorship program permits students to test their interests and apply their knowledge and aptitude in a real-life setting, working with professionals who have chosen to share their insights and expertise.</div>
#  </div>
#  </a>
#  </div>
#  <div class="view__row">
#  <a class="node node--type-section-page node--display-mode-card" href="/academics/pe-health-driver-education" role="article">
#  <div aria-label="photo of wall with figures playing sports" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Academics%20-%20PE_0.jpg?h=e0d9a4bb&amp;itok=mMkltxeY');"></div>
#  <div class="node__content">
#  <h2 class="node__title">PE, Health, and Driver Education</h2>
#  <div class="node__summary">The two-year physical education and health program emphasizes health and physical fitness, as well as individual and team sports.</div>
#  </div>
#  </a>
#  </div>
#  <div class="view__row">
#  <a class="node node--type-section-page node--display-mode-card" href="/academics/research-program" role="article">
#  <div aria-label="photo of microscope" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Research%20Program_2.jpg?h=e0d9a4bb&amp;itok=UEGaPF3Q');"></div>
#  <div class="node__content">
#  <h2 class="node__title">Research Program at TJ</h2>
#  <div class="node__summary">Our unique research program consists of specialized research laboratories, a mentorship program, and tjSTAR.</div>
#  </div>
#  </a>
#  </div>
#  <div class="view__row">
#  <a class="node node--type-section-page node--display-mode-card" href="/academics/science-and-technology" role="article">
#  <div aria-label="photo of students doing science experiement" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Academics-SciTech_0.jpg?h=d320664f&amp;itok=7VmyoN8W');"></div>
#  <div class="node__content">
#  <h2 class="node__title">Science and Technology</h2>
#  <div class="node__summary">Each student will complete four years of laboratory science beginning with Biology (integrated with English as well as Design and Technology) followed by Chemistry, Physics, and Geosystems.</div>
#  </div>
#  </a>
#  </div>
#  <div class="view__row">
#  <a class="node node--type-section-page node--display-mode-card" href="/academics/world-languages" role="article">
#  <div aria-label="photo of globe and language dictionaries" class="node__header" role="image" style="background-image: url('https://tjhsst.fcps.edu/sites/default/files/styles/card/public/media/hero/Academics%20-%20World%20Languages%20Main%20New.jpg?h=e0d9a4bb&amp;itok=vR9dEnBQ');"></div>
#  <div class="node__content">
#  <h2 class="node__title">World Languages</h2>
#  <div class="node__summary">The World Languages Department goal is to develop oral proficiency in the modern languages while instilling an awareness and appreciation of the cultures.</div>
#  </div>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </section>
#  <div class="layout-constrain--narrow">
#  <section class="section section--callout fcps-color--bg-light2">
#  <div class="section__text">
#  <h3>FCPSon</h3>
#  </div>
#  <div class="">
#  <a class="button" href="https://www.fcps.edu/resources/technology/fcpson" target="_blank">Learn about the one-to-one laptop program</a>
#  </div>
#  </section>
#  </div>
#  <div class="layout-constrain--narrow">
#  <section class="section section--callout fcps-color--bg-light2">
#  <div class="section__text">
#  <h3></h3>
#  </div>
#  <div class="">
#  <a class="button" href="https://www.fcps.edu/academics/grading-and-reporting" target="_blank">Learn about FCPS Grading and Reporting</a>
#  </div>
#  </section>
#  </div>
#  <div class="views-element-container">
#  </div>
#  </div>
#  </article>
#  </div>
#  </main>
#  <footer class="footer" role="contentinfo">
#  <div class="region region-footer">
#  <div class="button-bar">
#  <div class="button-bar__content">
#  Stay updated with what's happening at Thomas Jefferson High School for Science and Technology with <em>News You Choose</em> <a class="button button--orange" href="https://public.govdelivery.com/accounts/VAEDUFCPS/subscriber/topics?qsp=Jefferson_HS">Sign Up Now</a>
#  </div>
#  </div>
#  <ul class="nav nav--footer-menu">
#  <li class="nav__item">
#  <a class="nav__link" href="https://lms.fcps.edu/" title="Schoology">Schoology</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" href="https://www.fcps.edu/student-information-system-sis">SIS</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" href="http://www.fcpsschools.net/" title="Google Workspace">Google Workspace</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" data-drupal-link-system-path="node/1559" href="/library">Library</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" href="http://fcps.nutrislice.com/">Lunch Menus</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" href="https://www.myschoolbucks.com/">MySchoolBucks</a>
#  </li>
#  <li class="nav__item">
#  <a class="nav__link" href="https://www.fcps.edu/careers/employee-resources">Employee Resources</a>
#  </li>
#  </ul>
#  <ul class="action-grid">
#  <li class="action-grid__item">
#  <a class="action-grid__link" href="/about/bell-schedules">
#  <img alt="an icon of a school bell" height="91" loading="lazy" src="/sites/default/files/media/promo/icon-bell.png" width="81"/>
#  <div class="action-grid__item-description"></div>
#  <div class="action-grid__action">Bell Schedule</div>
#  </a>
#  </li>
#  <li class="action-grid__item">
#  <a class="action-grid__link" href="/library">
#  <img alt="an icon of a book" height="91" loading="lazy" src="/sites/default/files/media/promo/icon-book-yellow.png" width="66"/>
#  <div class="action-grid__item-description"></div>
#  <div class="action-grid__action">Library</div>
#  </a>
#  </li>
#  <li class="action-grid__item">
#  <a class="action-grid__link" href="http://fcps.nutrislice.com/menu/thomas-jefferson-high-school/hs-lunch/">
#  <img alt="icon of food" height="91" loading="lazy" src="/sites/default/files/media/promo/icon-lunch.png" width="110"/>
#  <div class="action-grid__item-description"></div>
#  <div class="action-grid__action">Lunch Menu</div>
#  </a>
#  </li>
#  <li class="action-grid__item">
#  <a class="action-grid__link" href="/contact">
#  <img alt="an icon of an envelope" height="91" loading="lazy" src="/sites/default/files/media/promo/icon-contact.png" width="93"/>
#  <div class="action-grid__item-description"></div>
#  <div class="action-grid__action">Contact Us</div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="footer-meta">
#  <div class="footer-meta__school fcps-color--bg-light2">
#  <div class="layout-constrain">
#  <div class="footer-meta__school-inner">
#  <div class="footer-meta__school-info">
#  <a href="https://www.google.com/maps/place/6560+Braddock+Rd%0D%0AAlexandria+VA+22312" target="_blank">
#  <img alt="Home" src="/sites/default/files/TJ%20LogoTransparent.png"/>
#  <span>Thomas Jefferson High School for Science and Technology
#  <address>
#  6560 Braddock Rd
#  Alexandria VA 22312
#  </address>
#  </span>
#  </a>
#  </div>
#  <div class="footer-meta__school-contact">
#  <div><strong>Main Office</strong></div>
#  <div><a href="tel:703-750-8300">703-750-8300</a></div>
#  <div>8:00 a.m. - 4:15 p.m.</div>
#  </div>
#  <div class="footer-meta__school-contact">
#  <div><strong>Attendance</strong></div>
#  <div><a href="tel:703-750-8315 ">703-750-8315 </a></div>
#  <div><a href="/cdn-cgi/l/email-protection#33675b5c5e5240795655555641405c5d7b5a545b1d724747565d57525d505673555043401d565746"><span class="__cf_email__" data-cfemail="1f4b7770727e6c557a79797a6d6c707157767877315e6b6b7a717b7e717c7a5f797c6f6c317a7b6a">[email protected]</span></a></div>
#  <div><p><a href="/about/attendance">Attendance Procedures</a></p></div>
#  </div>
#  <div class="footer-meta__school-contact">
#  <div><strong>Principal</strong></div>
#  <div>Ann Bonitatibus</div>
#  <div>
#  <a data-mail-to="naobavgngvoh/ng/spcf/qbg/rqh" data-replace-inner="" href="#" target="_blank">
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="footer-meta__social fcps-color--bg-dark1">
#  <ul class="social-links">
#  <li><a class="social-links__twitter" href="https://twitter.com/TJAnnB" target="_blank">Twitter</a></li>
#  </ul>
#  </div>
#  <div class="footer-meta__logo">
#  <a class="footer-meta__logo-link" href="https://www.fcps.edu">Fairfax County Public Schools</a>
#  </div>
#  <ul class="footer-meta__links">
#  <li>
#  <a href="https://www.fcps.edu/about-fcps/policies-regulations-and-notices/web-accessibility-guidelines">Web Accessibility Guidelines</a>
#  </li>
#  <li>
#  <a href="https://www.fcps.edu/about-fcps/policies-regulations-and-notices/virginia-freedom-information-act-vfoia">Freedom of Information Act</a>
#  </li>
#  <li>
#  <a href="https://www.fcps.edu/about-fcps/policies-regulations-and-notices">Policies and Regulations</a>
#  </li>
#  <li>
#  <a href="https://www.fcps.edu/about-fcps/policies-regulations-and-notices/web-privacy-policy">Web Privacy Policy</a>
#  </li>
#  <li>
#  <a href="https://www.fcps.edu/nondiscrimination">Nondiscrimination</a>
#  </li>
#  </ul>
#  <div class="footer-meta__copyright">© 2022 Fairfax County Public Schools, Fairfax County, Virginia</div>
#  </div>
#  </footer>
#  </div>
#  </div>
#  <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script data-drupal-selector="drupal-settings-json" type="application/json">{"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"node\/323","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"back_to_top":{"back_to_top_button_trigger":"100","back_to_top_prevent_on_mobile":0,"back_to_top_prevent_in_admin":0,"back_to_top_button_type":"image","back_to_top_button_text":"Back to top"},"data":{"extlink":{"extTarget":true,"extTargetNoOverride":false,"extNofollow":true,"extNoreferrer":false,"extFollowNoOverride":false,"extClass":"ext","extLabel":"(link is external)","extImgClass":false,"extSubdomains":false,"extExclude":"","extInclude":"","extCssExclude":"","extCssExplicit":"main","extAlert":false,"extAlertText":"This link will take you to an external web site. We are not responsible for their content.","mailtoClass":"mailto","mailtoLabel":"(link sends email)","extUseFontAwesome":false,"extIconPlacement":"append","extFaLinkClasses":"fa fa-external-link","extFaMailtoClasses":"fa fa-envelope-o","whitelistedDomains":null}},"fcps_site":{"menu":{"title":"TJHSST"}},"facility_id":"2300","alerts_target_url":"https:\/\/www.fcps.edu","user":{"uid":0,"permissionsHash":"3c063834cd7d9b66cb3808ecbf16a721ec0e05883d3472f2619f3340cfc1e1cb"}}</script>
#  <script src="/sites/default/files/js/js_Se3GPboWxub0W9h6A2zhgvoWWf2zf1onALy2P8SDjQc.js"></script>
#  <script src="//addevent.com/libs/atc/1.6.1/atc.min.js"></script>
#  <script src="/sites/default/files/js/js_Qzn2IxD_JJvxdF7AjTZRj1s6EaCeJgLol-al2daelqs.js"></script>
#  <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"869a1a293e","applicationID":"71440368","transactionName":"ZwEAY0BXXUZZBREKDV5LI1RGX1xbFxYEBAdvBwNUWlM=","queueTime":0,"applicationTime":23,"atts":"S0YDFQhNTkg=","errorBeacon":"bam.nr-data.net","agent":""}</script><script crossorigin="anonymous" data-cf-beacon='{"rayId":"6dbfa490ec48f060","token":"39dceb23f25b43b58ac8cd81068dccfa","version":"2021.12.0","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194"></script>
#  </body>
#  </html>,
#  '\n']

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
soup.findAll(['p'])
# Out:
# [<p>TJHSST provides a comprehensive curriculum, emphasizing the sciences, mathematics, and technology.</p>,
#  <p>All seniors are required to complete a technology laboratory project as the culmination of their TJHSST academic experience, either in one of the specialized <a href="/research-program">Research Laboratories</a>, or through the <a href="/academics/mentorship">Mentorship Program</a>.</p>,
#  <p>The TJHSST school day begins at 8:40 a.m. and ends at 4:00 p.m. Seven periods are devoted to academic coursework and one period is designated for <a href="/student-life-and-activities">student activities</a> and activity-related coursework. Student and faculty research is supported by the <a href="/library">Geoff Jones Library</a>. Many online resources are made available to students and staff, including Mathematica and numerous online databases.</p>,
#  <p>The foundation of the curricular program at TJHSST focuses on an interdisciplinary approach aimed at maximizing the full potential of each student's intellectual, technological and affective skills. Course work such as the ninth grade <strong>IBET program</strong> and <a href="/academics/humanities">humanities</a> courses are driven by six learning methodologies:</p>,
#  <p>The following programs are unique to TJHSST and are among some of the specialized course work required of our students:</p>,
#  <p> </p>,
#  <p><a href="/about/attendance">Attendance Procedures</a></p>]

# %%
f = open('tj', 'w')
for line in soup.findAll('p'):
    f.write(str(line))
f.close()
